# %% [markdown]
# # 00 - Setup\n\nValidate environment, config, and raw notes directory.

# %%
from pathlib import Path\nfrom src.config import settings\n\nprint('RAW_NOTES_DIR:', settings.raw_notes_dir)\nPath(settings.raw_notes_dir).mkdir(parents=True, exist_ok=True)\nprint('Exists:', Path(settings.raw_notes_dir).exists())
